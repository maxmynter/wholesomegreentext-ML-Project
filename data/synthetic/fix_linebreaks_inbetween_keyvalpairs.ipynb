# %%
import json
import re
import os

def list_files(directory):
    """ List all files in a given directory """
    return [file for file in os.listdir(directory) if os.path.isfile(os.path.join(directory, file))]

# %%
def regex_fixer(sub_function):
    def fixer(file_paths):
        for file_path in file_paths:
            try:
                with open(file_path, 'r') as file:
                    json.load(file)
                print(f"{file_path}: JSON is valid, no changes made.")
            except json.JSONDecodeError as e:
                with open(file_path, 'r') as file:
                    file_content = file.read()
                fixed_content = sub_function(file_content)

                try:
                    # Validate if the fixed content is a valid JSON
                    json.loads(fixed_content)
                    # If valid, overwrite the file
                    with open(file_path, 'w') as file:
                        file.write(fixed_content)
                    print(f"{file_path}: fixed.")
                except json.JSONDecodeError:
                    # If still invalid, report and leave as is
                    print(f"{file_path}: Could not fix the JSON structure.")
    return fixer

fix_space_between_keyvalpairs = regex_fixer(lambda text: re.sub(r'"\s*[^":]*\s*"(?=\s*\d+\s*":\s*">)', '","', text))

# %%
def replace_internal_quotes(match):
    # Get the match string
    string = match.group()

    # If the match is at the start or end of the string, keep it unchanged
    if string.startswith(': ">') or string.endswith('",'):
        return string

    # Otherwise, replace the internal double quote
    return string.replace('"', "'")

fix_doublequotes_in_values = regex_fixer(lambda text: re.sub(r': ".*?"|".*?"(,|$)',  replace_internal_quotes, text))

# %%
directory_path = './thanks_output/'
files = [file for file in list_files(directory_path) if file.endswith(".json")]

# %%
fix_doublequotes_in_values([os.path.join(directory_path, file) for file in files])
# Out:
# ./thanks_output/hjbRO7pcc1Vy.json: Could not fix the JSON structure.
# ./thanks_output/tUCqxSEss72p.json: Could not fix the JSON structure.
# ./thanks_output/RADzk77t0cLN.json: Could not fix the JSON structure.
# ./thanks_output/jOlk10JMb6tK.json: Could not fix the JSON structure.
# ./thanks_output/02rAtvTP3veR.json: Could not fix the JSON structure.
# ./thanks_output/gmJDpygbX6v6.json: Could not fix the JSON structure.
# ./thanks_output/M7BDpgL9rV9w.json: Could not fix the JSON structure.
# ./thanks_output/3LVPLB42KfS2.json: Could not fix the JSON structure.
# ./thanks_output/w0DDjD26Wdh9.json: Could not fix the JSON structure.
# ./thanks_output/K3D7m1nNkMD6.json: Could not fix the JSON structure.
# ./thanks_output/9Q6mMVUbMALH.json: Could not fix the JSON structure.
# ./thanks_output/v6DzpS6jo3wu.json: Could not fix the JSON structure.
# ./thanks_output/KzsGTLFgnFJ3.json: Could not fix the JSON structure.
# ./thanks_output/jKkEQF9x2kwa.json: Could not fix the JSON structure.
# ./thanks_output/UfrS4OXs7cCA.json: JSON is valid, no changes made.
# ./thanks_output/4c0MGLdX4RkS.json: Could not fix the JSON structure.
# ./thanks_output/40K1gnBds0Ux.json: Could not fix the JSON structure.
# ./thanks_output/mQiLB9mT28ei.json: Could not fix the JSON structure.
# ./thanks_output/Aio7rqr9TviN.json: Could not fix the JSON structure.
# ./thanks_output/KGXu8kqtozgt.json: Could not fix the JSON structure.
# ./thanks_output/ivpiWjdlYICz.json: Could not fix the JSON structure.
# ./thanks_output/mvUvryB6e34O.json: Could not fix the JSON structure.
# ./thanks_output/lWst93f4XAj2.json: Could not fix the JSON structure.
# ./thanks_output/FThQALlbgpEc.json: Could not fix the JSON structure.
# ./thanks_output/L1Orao1R65GJ.json: Could not fix the JSON structure.
# ./thanks_output/il1I54O8TzYn.json: Could not fix the JSON structure.
# ./thanks_output/tenmf113JQVF.json: Could not fix the JSON structure.
# ./thanks_output/vZEdTfj3JYl1.json: Could not fix the JSON structure.
# ./thanks_output/aKGRX2d6zBdi.json: Could not fix the JSON structure.
# ./thanks_output/xUvgPUhoccZL.json: Could not fix the JSON structure.
# ./thanks_output/YmJJRg4vqYDY.json: Could not fix the JSON structure.
# ./thanks_output/os74X1mipwtM.json: Could not fix the JSON structure.
# ./thanks_output/FwI6vap94HG7.json: Could not fix the JSON structure.
# ./thanks_output/Y0GF0IEfhcSV.json: Could not fix the JSON structure.
# ./thanks_output/4lTesyoMpB0b.json: Could not fix the JSON structure.
# ./thanks_output/Xu2ZooU73LvN.json: Could not fix the JSON structure.
# ./thanks_output/oJofOO1yR93T.json: Could not fix the JSON structure.
# ./thanks_output/t8psPiqCpBaA.json: Could not fix the JSON structure.
# ./thanks_output/Ftl3qG0jNzqL.json: Could not fix the JSON structure.
# ./thanks_output/m68TDCAaVnmv.json: Could not fix the JSON structure.
# ./thanks_output/8MkWDz0G4T2N.json: Could not fix the JSON structure.
# ./thanks_output/Kldy7dEQgihq.json: Could not fix the JSON structure.
# ./thanks_output/V0QKCEH2FefO.json: Could not fix the JSON structure.
# ./thanks_output/SuCSzRfEJoPV.json: Could not fix the JSON structure.
# ./thanks_output/rN6PhPsApt6o.json: Could not fix the JSON structure.
# ./thanks_output/NTXJWs5zF9iE.json: Could not fix the JSON structure.
# ./thanks_output/bg41j5TRFA7G.json: Could not fix the JSON structure.
# ./thanks_output/ELFct71vSl7u.json: Could not fix the JSON structure.
# ./thanks_output/NpG3QBcEGb39.json: Could not fix the JSON structure.
# ./thanks_output/xHCNqmkWqDBb.json: Could not fix the JSON structure.
# ./thanks_output/8Qs1xYy12OVv.json: Could not fix the JSON structure.
# ./thanks_output/IasOJTwmeCxi.json: Could not fix the JSON structure.
# ./thanks_output/nlQJSjC7Tt78.json: Could not fix the JSON structure.
# ./thanks_output/6jVXhYkFDbI1.json: Could not fix the JSON structure.
# ./thanks_output/O1qXBMR3mBNM.json: Could not fix the JSON structure.
# ./thanks_output/ge5X21xBZ50m.json: Could not fix the JSON structure.
# ./thanks_output/QMzaSD3o6vyj.json: Could not fix the JSON structure.
# ./thanks_output/NTbKarT1zNJ2.json: Could not fix the JSON structure.
# ./thanks_output/jzde4aJXym4c.json: Could not fix the JSON structure.
# ./thanks_output/XLK2lUfhSeLA.json: Could not fix the JSON structure.
# ./thanks_output/v7T45enShWhf.json: Could not fix the JSON structure.
# ./thanks_output/JoazASgqH7O9.json: Could not fix the JSON structure.
# ./thanks_output/qAQqeXB0CfC3.json: Could not fix the JSON structure.
# ./thanks_output/tuMvVn3pE6ln.json: Could not fix the JSON structure.
# ./thanks_output/DZeT6WZ8s4lY.json: Could not fix the JSON structure.
# ./thanks_output/0yOGOj9kPnb2.json: Could not fix the JSON structure.
# ./thanks_output/dB62OUbgQtmf.json: Could not fix the JSON structure.
# ./thanks_output/sVdJQhjEnFm4.json: Could not fix the JSON structure.
# ./thanks_output/zbaBnevaLw8Y.json: JSON is valid, no changes made.
# ./thanks_output/IXDX1p1iTYYj.json: Could not fix the JSON structure.
# ./thanks_output/vDjHRi3Vjq7m.json: Could not fix the JSON structure.
# ./thanks_output/TBoG57OLAt59.json: Could not fix the JSON structure.
# ./thanks_output/p4FNsmC3MSqr.json: Could not fix the JSON structure.
# ./thanks_output/D5AaLfHQt67P.json: Could not fix the JSON structure.
# ./thanks_output/TkVEEulB2zM1.json: Could not fix the JSON structure.
# ./thanks_output/CDzcdEK5Smrn.json: Could not fix the JSON structure.
# ./thanks_output/S7ksZBdCnWWB.json: Could not fix the JSON structure.
# ./thanks_output/jomGJKha8OPe.json: Could not fix the JSON structure.
# ./thanks_output/WbqS1Ph9FaEq.json: Could not fix the JSON structure.
# ./thanks_output/BT8z3b0bANsX.json: Could not fix the JSON structure.
# ./thanks_output/WEZct3WYSkV0.json: JSON is valid, no changes made.
# ./thanks_output/ox7KBU6XPnMr.json: Could not fix the JSON structure.
# ./thanks_output/dXzhRWCyw7PO.json: Could not fix the JSON structure.
# ./thanks_output/DL4samZ95aeT.json: Could not fix the JSON structure.
# ./thanks_output/ItRy1Uaxoz3f.json: Could not fix the JSON structure.
# ./thanks_output/zTS8Qceg38eK.json: Could not fix the JSON structure.
# ./thanks_output/Lbz1rxxS2SGG.json: JSON is valid, no changes made.
# ./thanks_output/gCszrXHKidA0.json: Could not fix the JSON structure.
# ./thanks_output/mBeuw8SEM7EJ.json: JSON is valid, no changes made.
# ./thanks_output/JgzWhDx3sPmR.json: Could not fix the JSON structure.
# ./thanks_output/Jr8i1PZQeMjl.json: JSON is valid, no changes made.
# ./thanks_output/aqyOjQu49KEo.json: Could not fix the JSON structure.
# ./thanks_output/ONcz1HU2zyo3.json: Could not fix the JSON structure.
# ./thanks_output/RrJuWtQDpHWD.json: Could not fix the JSON structure.
# ./thanks_output/jyjLZmvgKMvX.json: Could not fix the JSON structure.
# ./thanks_output/C2bpSTcMZRku.json: Could not fix the JSON structure.
# ./thanks_output/tP9JKp0XNUIF.json: JSON is valid, no changes made.
# ./thanks_output/tRC1pCZu5RCH.json: Could not fix the JSON structure.
# ./thanks_output/dBcOJG97Mu17.json: Could not fix the JSON structure.
# ./thanks_output/Fqp9u5mGJk80.json: Could not fix the JSON structure.
# ./thanks_output/r1ONMwbklTNe.json: JSON is valid, no changes made.
# ./thanks_output/ugvIMnjju8mb.json: JSON is valid, no changes made.
# ./thanks_output/Ke9CHyiksmAR.json: Could not fix the JSON structure.
# ./thanks_output/HMvbZNz6EOSf.json: Could not fix the JSON structure.
# ./thanks_output/WWksh05ZzFhm.json: Could not fix the JSON structure.
# ./thanks_output/qXpXfj7ZVK4q.json: Could not fix the JSON structure.
# ./thanks_output/qSoKrE0zbf7V.json: Could not fix the JSON structure.
# ./thanks_output/VAyXDOLCzLzJ.json: Could not fix the JSON structure.
# ./thanks_output/xHCegmooyTwa.json: Could not fix the JSON structure.
# ./thanks_output/FAwZYYQYy3bk.json: Could not fix the JSON structure.
# ./thanks_output/FeGHl5Y6nE7I.json: Could not fix the JSON structure.
# ./thanks_output/pKINGenoyXQA.json: Could not fix the JSON structure.
# ./thanks_output/sOAbgwpDTp57.json: Could not fix the JSON structure.
# ./thanks_output/PtLkqKIFIcGF.json: Could not fix the JSON structure.
# ./thanks_output/SGRJeIESeUC2.json: Could not fix the JSON structure.
# ./thanks_output/oXZFuErZ0Y1X.json: Could not fix the JSON structure.
# ./thanks_output/yAkbdwXPgPUd.json: JSON is valid, no changes made.
# ./thanks_output/vDOgEu9SctmF.json: Could not fix the JSON structure.
# ./thanks_output/Ev2lMTeuXVkh.json: Could not fix the JSON structure.
# ./thanks_output/dC1O44II64AR.json: Could not fix the JSON structure.
# ./thanks_output/rKYH6OdXaANb.json: Could not fix the JSON structure.
# ./thanks_output/9AS65UbdLnwq.json: Could not fix the JSON structure.
# ./thanks_output/zkwRqblPzjFe.json: JSON is valid, no changes made.
# ./thanks_output/fY4k5vTosiGP.json: Could not fix the JSON structure.
# ./thanks_output/e3lSD6CdOLWH.json: Could not fix the JSON structure.
# ./thanks_output/uP9CFBS1CcdM.json: Could not fix the JSON structure.
# ./thanks_output/XwZ3Qhh5EW5G.json: JSON is valid, no changes made.
# ./thanks_output/3BKy2cWU73x1.json: Could not fix the JSON structure.
# ./thanks_output/WvbMgMZjn3C1.json: Could not fix the JSON structure.
# ./thanks_output/O2NXxycUuHzk.json: Could not fix the JSON structure.
# ./thanks_output/apEMCLJVVb06.json: Could not fix the JSON structure.
# ./thanks_output/wJ4M8DbBe5Rd.json: Could not fix the JSON structure.
# ./thanks_output/m9e90z33zWrn.json: Could not fix the JSON structure.
# ./thanks_output/vNZJLW9mUDaH.json: Could not fix the JSON structure.
# ./thanks_output/vUQT3qL8P4iJ.json: Could not fix the JSON structure.
# ./thanks_output/hhrlNz5NkLa3.json: Could not fix the JSON structure.
# ./thanks_output/z0lsT15kYaJm.json: Could not fix the JSON structure.
# ./thanks_output/PCwjq6qW0cKt.json: Could not fix the JSON structure.
# ./thanks_output/DrTRglDz3ZSq.json: Could not fix the JSON structure.
# ./thanks_output/FSGhjLyQ8AsV.json: Could not fix the JSON structure.
# ./thanks_output/meJtmNd2HOne.json: Could not fix the JSON structure.
# ./thanks_output/uMYkXby8PPU3.json: Could not fix the JSON structure.
# ./thanks_output/NpJWGApxJUms.json: Could not fix the JSON structure.
# ./thanks_output/5LpgfMYjcgpk.json: Could not fix the JSON structure.
# ./thanks_output/3ZDvHQdN0ghG.json: Could not fix the JSON structure.
# ./thanks_output/3NrJcDsrjHk4.json: Could not fix the JSON structure.
# ./thanks_output/cbfnaMn9gg8j.json: Could not fix the JSON structure.
# ./thanks_output/Y6y03533O5Fh.json: JSON is valid, no changes made.
# ./thanks_output/2IYMCho1Tt02.json: Could not fix the JSON structure.
# ./thanks_output/umGv3BHq3Q2I.json: Could not fix the JSON structure.
# ./thanks_output/2vdvcwkjv1QY.json: JSON is valid, no changes made.
# ./thanks_output/N1Y9KCsSd4hf.json: Could not fix the JSON structure.
# ./thanks_output/qHGZOBUb5PNf.json: Could not fix the JSON structure.
# ./thanks_output/MEzzRD9P8L5C.json: JSON is valid, no changes made.
# ./thanks_output/3fNVmWocBIJX.json: Could not fix the JSON structure.
# ./thanks_output/THQGjRwI4wkE.json: Could not fix the JSON structure.
# ./thanks_output/u17bMAFmq6ai.json: Could not fix the JSON structure.
# ./thanks_output/eOag1oUSktVl.json: JSON is valid, no changes made.
# ./thanks_output/Ln9oiVDaDNTZ.json: Could not fix the JSON structure.
# ./thanks_output/JcoDkgWw6wot.json: Could not fix the JSON structure.
# ./thanks_output/F30wtLU6el91.json: Could not fix the JSON structure.
# ./thanks_output/t1JkJ9QSau7h.json: Could not fix the JSON structure.
# ./thanks_output/LazHA8MdZRwo.json: Could not fix the JSON structure.

# %%
fix_space_between_keyvalpairs([os.path.join(directory_path, file) for file in files])
# Out:
# ./simple_output/ZpVWXZ5Rm1d4.json: Could not fix the JSON structure.
# ./simple_output/8IL6BlAeEKzq.json: fixed.
# ./simple_output/5xMqOyU4olMk.json: fixed.
# ./simple_output/SguE61fHqAik.json: fixed.
# ./simple_output/489vzcyWYNEa.json: fixed.
# ./simple_output/XPfQCZrRtUJh.json: fixed.
# ./simple_output/lWpMnBWGcCWV.json: fixed.
# ./simple_output/7Qofwz69dNuW.json: fixed.
# ./simple_output/VLgNoHpQS7iV.json: Could not fix the JSON structure.
# ./simple_output/S7x9KsqiyNGX.json: Could not fix the JSON structure.
# ./simple_output/jwxsDk8H9VHN.json: fixed.
# ./simple_output/ChLU4F1TGtZS.json: fixed.
# ./simple_output/VdgnfWj9M3Or.json: Could not fix the JSON structure.
# ./simple_output/XHlKVNlSnHRD.json: Could not fix the JSON structure.
# ./simple_output/mdKHFSgniozP.json: Could not fix the JSON structure.
# ./simple_output/t08taoiH8cPF.json: Could not fix the JSON structure.
# ./simple_output/iw8R6QqiTe8I.json: fixed.
# ./simple_output/ikwgLT1G5fN3.json: fixed.
# ./simple_output/J0ptS4crljtU.json: fixed.
# ./simple_output/JivOKWVdTTkP.json: Could not fix the JSON structure.
# ./simple_output/ZuyrZ2zbtTfh.json: fixed.
# ./simple_output/wK46zdqz5mgp.json: Could not fix the JSON structure.
# ./simple_output/cZdwe4cJrTGe.json: fixed.
# ./simple_output/7InPysR0gyL7.json: fixed.
# ./simple_output/5SfyogrQWrrl.json: Could not fix the JSON structure.
# ./simple_output/Ok5lBOhXeMq4.json: fixed.
# ./simple_output/8WWTeqBcVUqE.json: JSON is valid, no changes made.
# ./simple_output/BDbZRBOk6cks.json: fixed.
# ./simple_output/pveVBeiQGXkP.json: Could not fix the JSON structure.
# ./simple_output/gajo3X11Ao2m.json: Could not fix the JSON structure.
# ./simple_output/mbEIOOprUAhA.json: Could not fix the JSON structure.
# ./simple_output/2D6X9QojRqCf.json: Could not fix the JSON structure.
# ./simple_output/lSz8W5FbBWvd.json: fixed.
# ./simple_output/krYHWRvcz8Tg.json: Could not fix the JSON structure.
# ./simple_output/tpTose7QTv4B.json: fixed.
# ./simple_output/BnG2MMky1yZg.json: Could not fix the JSON structure.
# ./simple_output/cFqgeyBOJFdH.json: Could not fix the JSON structure.
# ./simple_output/vY87PXqvDPvN.json: Could not fix the JSON structure.
# ./simple_output/8dNi7VbcvA16.json: Could not fix the JSON structure.
# ./simple_output/6pDFhvmYQT3n.json: Could not fix the JSON structure.
# ./simple_output/Fm2KJHzeQYXm.json: fixed.
# ./simple_output/DXr8WZ13w186.json: fixed.
# ./simple_output/16VESBeQ4LbR.json: fixed.
# ./simple_output/Zr5JzmQlwf2e.json: Could not fix the JSON structure.
# ./simple_output/l4BLBYwo3ZnD.json: Could not fix the JSON structure.
# ./simple_output/oNoH8eSjAram.json: Could not fix the JSON structure.
# ./simple_output/cFdHy72CiQkv.json: fixed.
# ./simple_output/W4fisXEAGHgz.json: Could not fix the JSON structure.
# ./simple_output/VEojXa58OcPU.json: fixed.
# ./simple_output/7x9h1FIuYSAA.json: fixed.
# ./simple_output/4YP6TZopZYOc.json: Could not fix the JSON structure.
# ./simple_output/swhozRgvxr96.json: fixed.
# ./simple_output/We31jBLKBmch.json: Could not fix the JSON structure.
# ./simple_output/N3QY98tpd69n.json: Could not fix the JSON structure.
# ./simple_output/SUpkQqF80pY3.json: fixed.
# ./simple_output/i80bdt8qDjfd.json: Could not fix the JSON structure.
# ./simple_output/mqqvfn3VqZGZ.json: Could not fix the JSON structure.
# ./simple_output/pFj70SdY98Xe.json: fixed.
# ./simple_output/6bsrzmx0uuGg.json: Could not fix the JSON structure.
# ./simple_output/wwCooeVSdr9P.json: Could not fix the JSON structure.
# ./simple_output/x1f0l8NhEgRo.json: fixed.
# ./simple_output/q69XfdcLZnTH.json: Could not fix the JSON structure.
# ./simple_output/FUgif46SKWAe.json: Could not fix the JSON structure.
# ./simple_output/ZNLfmiBj4tOG.json: Could not fix the JSON structure.
# ./simple_output/7vjuCpZm0AyE.json: Could not fix the JSON structure.
# ./simple_output/CEHymNxK9zfY.json: fixed.
# ./simple_output/CkXN0xRSpvGb.json: Could not fix the JSON structure.
# ./simple_output/05XHdjabzhZK.json: Could not fix the JSON structure.
# ./simple_output/l5saaQguHhHq.json: JSON is valid, no changes made.
# ./simple_output/gKCauK68z0I5.json: Could not fix the JSON structure.
# ./simple_output/hvfcQuzEx3Xn.json: Could not fix the JSON structure.
# ./simple_output/39zGIKupqnHK.json: Could not fix the JSON structure.
# ./simple_output/cQvjdfJAH3aP.json: Could not fix the JSON structure.
# ./simple_output/NwwADJs773y1.json: Could not fix the JSON structure.
# ./simple_output/jx7EBXNDEFGv.json: JSON is valid, no changes made.
# ./simple_output/El74hHfrE3cF.json: Could not fix the JSON structure.
# ./simple_output/ktbzUo7CuENO.json: Could not fix the JSON structure.
# ./simple_output/2teX0cytdbaH.json: fixed.
# ./simple_output/LGHwNjFihT6M.json: Could not fix the JSON structure.
# ./simple_output/RbKYIU1l0FqW.json: Could not fix the JSON structure.
# ./simple_output/iuSIEuH6mkOV.json: Could not fix the JSON structure.
# ./simple_output/daaH8jnLccnl.json: Could not fix the JSON structure.
# ./simple_output/Rb1RfuLeFTtK.json: Could not fix the JSON structure.
# ./simple_output/NrQPD25bi4Zl.json: Could not fix the JSON structure.
# ./simple_output/O5A5UwhLTfrm.json: Could not fix the JSON structure.
# ./simple_output/5zdiHUjQ04Dn.json: fixed.
# ./simple_output/t64epGmXOuIk.json: Could not fix the JSON structure.
# ./simple_output/smj6sVCSS7bN.json: Could not fix the JSON structure.
# ./simple_output/uuJZzoC9juI9.json: Could not fix the JSON structure.
# ./simple_output/YIQ2QLCMlRli.json: fixed.
# ./simple_output/GAjEezHMGzQn.json: Could not fix the JSON structure.
# ./simple_output/ZqGEWwZBNZTJ.json: Could not fix the JSON structure.
# ./simple_output/1sKBbh5JNRZz.json: fixed.
# ./simple_output/YHdA8ZHdGNFE.json: Could not fix the JSON structure.
# ./simple_output/UgkpizfJhWRP.json: Could not fix the JSON structure.
# ./simple_output/mIMph10SH3Rc.json: fixed.
# ./simple_output/K3gOTvoCyHGO.json: Could not fix the JSON structure.
# ./simple_output/dSR73UvCQY3z.json: Could not fix the JSON structure.
# ./simple_output/gY5Iy8NniQdL.json: Could not fix the JSON structure.
# ./simple_output/2UkhFgudsUJW.json: Could not fix the JSON structure.
# ./simple_output/nqjuwdsvSzrK.json: Could not fix the JSON structure.
# ./simple_output/FRCGqlHpnPRQ.json: Could not fix the JSON structure.
# ./simple_output/mAJR3DarijGH.json: Could not fix the JSON structure.
# ./simple_output/tp7Gl4886cE2.json: Could not fix the JSON structure.
# ./simple_output/m9Y268HJbgnC.json: Could not fix the JSON structure.
# ./simple_output/aeQI0pnI2tlY.json: Could not fix the JSON structure.
# ./simple_output/wdYGqXIzp26t.json: Could not fix the JSON structure.
# ./simple_output/E0KBnhgaBzFv.json: fixed.
# ./simple_output/YXo2Jcjnl9fA.json: fixed.
# ./simple_output/o0s7ELwzSSBq.json: Could not fix the JSON structure.
# ./simple_output/lrn2gH5UBggy.json: Could not fix the JSON structure.
# ./simple_output/z7wlyLd34AO4.json: fixed.
# ./simple_output/ARTIil5Si3UN.json: Could not fix the JSON structure.
# ./simple_output/h3p3OzaE8GQ4.json: Could not fix the JSON structure.
# ./simple_output/Onn2bCdryouI.json: Could not fix the JSON structure.
# ./simple_output/8ZrgAf1pB17h.json: Could not fix the JSON structure.
# ./simple_output/9PxndqJ6LCmA.json: fixed.
# ./simple_output/PF3xVO3f8VsM.json: fixed.
# ./simple_output/v0tInn3bDDzh.json: fixed.
# ./simple_output/nwKByN2qWQWj.json: fixed.
# ./simple_output/d9olobawqXg2.json: Could not fix the JSON structure.
# ./simple_output/BM4xxOLIu9TA.json: fixed.
# ./simple_output/FDQfULA9DVrI.json: Could not fix the JSON structure.
# ./simple_output/9UHm0zZU3jvi.json: Could not fix the JSON structure.
# ./simple_output/DD9m7pGMp8A7.json: Could not fix the JSON structure.
# ./simple_output/U2Ow1LOUek60.json: Could not fix the JSON structure.
# ./simple_output/7H6H5JKSEQ5S.json: fixed.
# ./simple_output/TsiVqHVp8pEi.json: fixed.
# ./simple_output/D1bAxKZOnIe3.json: Could not fix the JSON structure.
# ./simple_output/f5lTwPY2G5J3.json: Could not fix the JSON structure.
# ./simple_output/ZAMrzNG2wIgx.json: fixed.
# ./simple_output/ryXV5fkLLUNb.json: Could not fix the JSON structure.
# ./simple_output/hZ6nsU2N3Ts1.json: Could not fix the JSON structure.
# ./simple_output/kbgwjLePb5Fl.json: Could not fix the JSON structure.
# ./simple_output/Bd0LhGfS03Qd.json: Could not fix the JSON structure.
# ./simple_output/FQFxT0PzbTj4.json: Could not fix the JSON structure.
# ./simple_output/din7NdR3EOBO.json: Could not fix the JSON structure.
# ./simple_output/XUdcqxj6dZZC.json: Could not fix the JSON structure.
# ./simple_output/tmz1wI0J2NZb.json: fixed.
# ./simple_output/JCnrkaDQfHq8.json: fixed.
# ./simple_output/Zieb2QwlI3As.json: fixed.
# ./simple_output/a4yDacBOZajK.json: Could not fix the JSON structure.
# ./simple_output/zgmGYSYWRkEQ.json: Could not fix the JSON structure.
# ./simple_output/XoOOSuqrC84M.json: Could not fix the JSON structure.
# ./simple_output/fgovwXLH2nr1.json: Could not fix the JSON structure.
# ./simple_output/uG1WucQtKkOI.json: fixed.
# ./simple_output/MbFER03P5hYG.json: fixed.
# ./simple_output/HlUcfLJIUIRd.json: fixed.
# ./simple_output/4FDlD0IIXeXF.json: Could not fix the JSON structure.
# ./simple_output/byyhPbpEeF67.json: Could not fix the JSON structure.
# ./simple_output/OzcnGmBPfAcN.json: Could not fix the JSON structure.
# ./simple_output/scgn7QW8NfiF.json: Could not fix the JSON structure.
# ./simple_output/JWPFYP1hqnb7.json: Could not fix the JSON structure.
# ./simple_output/hHCoX6fmuWna.json: Could not fix the JSON structure.
# ./simple_output/KU1dGFPUqT8v.json: Could not fix the JSON structure.
# ./simple_output/e0HYYhg2VbNf.json: Could not fix the JSON structure.
# ./simple_output/j4GEuSayveqE.json: fixed.
# ./simple_output/9u3efcB8T2NW.json: fixed.
# ./simple_output/cFbne6kCAlhc.json: fixed.
# ./simple_output/QeJTVJxZHF24.json: fixed.
# ./simple_output/ZxJghnCM3Q6R.json: fixed.
# ./simple_output/Pc3icZppv1w7.json: Could not fix the JSON structure.
# ./simple_output/hNOrRgR2FGyL.json: fixed.
# ./simple_output/u2YU3S16gaDM.json: fixed.
# ./simple_output/GYVl490liA9k.json: fixed.
# ./simple_output/GLDi0S4vvgPr.json: fixed.
# ./simple_output/AvlvNoghOwq6.json: Could not fix the JSON structure.
# ./simple_output/nCFr3cWLnanb.json: fixed.
# ./simple_output/5OtIiHiziCrf.json: fixed.
# ./simple_output/KfuHXhdRRrZv.json: fixed.
# ./simple_output/gVGG4iJrc1jF.json: fixed.
# ./simple_output/4TWfjhfJZOPn.json: fixed.
# ./simple_output/zbyJPbuJTPsF.json: Could not fix the JSON structure.
# ./simple_output/ujZqkAplB4wu.json: fixed.
# ./simple_output/Z5dVHiBxix17.json: fixed.
# ./simple_output/6AXQAwxeF8Gs.json: Could not fix the JSON structure.
# ./simple_output/w2GrHjsp1K6S.json: Could not fix the JSON structure.
# ./simple_output/xEkXFX8XFg0O.json: Could not fix the JSON structure.
# ./simple_output/L5R4aEzTSXjw.json: Could not fix the JSON structure.
# ./simple_output/BQDxPbBcw9NF.json: Could not fix the JSON structure.
# ./simple_output/FG4euT8eJchX.json: fixed.
# ./simple_output/NlBmxK9bIZz8.json: Could not fix the JSON structure.
# ./simple_output/EZVpKwT2POGI.json: Could not fix the JSON structure.
# ./simple_output/3WMeB1n8kUKJ.json: Could not fix the JSON structure.
# ./simple_output/LlnvCtAjFE9g.json: fixed.
# ./simple_output/t19jSq4PSWm9.json: fixed.
# ./simple_output/dhYAxx2Zl6ja.json: Could not fix the JSON structure.
# ./simple_output/HHmecKgZNqol.json: fixed.
# ./simple_output/LgrztJivWgm3.json: Could not fix the JSON structure.
# ./simple_output/5JM9SCZuHtBz.json: fixed.
# ./simple_output/oPJGES63OdMZ.json: fixed.
# ./simple_output/bMefWmhsBjym.json: fixed.
# ./simple_output/IlKmLMxWSP2j.json: Could not fix the JSON structure.
# ./simple_output/UALH79Jl6kDl.json: fixed.
# ./simple_output/0oNYQ7D2bAp6.json: JSON is valid, no changes made.
# ./simple_output/KwtgpJvdIUWC.json: fixed.
# ./simple_output/awKWb7PCY8zj.json: fixed.
# ./simple_output/H1aIQGuSO3u3.json: Could not fix the JSON structure.
# ./simple_output/UxVlg09jaTjE.json: Could not fix the JSON structure.
# ./simple_output/dKPXweB5byVl.json: Could not fix the JSON structure.
# ./simple_output/vkP0oqARWiBh.json: Could not fix the JSON structure.
# ./simple_output/5nzvrhGTcVZQ.json: Could not fix the JSON structure.
# ./simple_output/kMszMPx31zMU.json: fixed.
# ./simple_output/PaWQJex6tkvr.json: Could not fix the JSON structure.
# ./simple_output/1PmW22f6iTNL.json: fixed.
# ./simple_output/OP7xXgTcRa9y.json: fixed.
# ./simple_output/ayTJ5sQ5nEbs.json: Could not fix the JSON structure.
# ./simple_output/0a03CqAdWJl4.json: JSON is valid, no changes made.
# ./simple_output/ORR8XrFDSZSh.json: fixed.
# ./simple_output/r1mlctCHIkgU.json: fixed.
# ./simple_output/E6j4QVVz5iaG.json: fixed.
# ./simple_output/Us1KQmE1dKne.json: fixed.
# ./simple_output/LyBKtacyKLcL.json: Could not fix the JSON structure.
# ./simple_output/KLdShOpfNh0O.json: Could not fix the JSON structure.
# ./simple_output/CQV83jkJQrRA.json: Could not fix the JSON structure.
# ./simple_output/JBUVxdcfGLln.json: Could not fix the JSON structure.
# ./simple_output/opgMVyc77Q1a.json: Could not fix the JSON structure.
# ./simple_output/MMdPIOfcJbXH.json: Could not fix the JSON structure.
# ./simple_output/F4eBnlGzGqzY.json: Could not fix the JSON structure.
# ./simple_output/1RJiccxrYGHb.json: Could not fix the JSON structure.
# ./simple_output/s1TATbh2LDG2.json: fixed.
# ./simple_output/QTneWuhgPim8.json: Could not fix the JSON structure.
# ./simple_output/4mmuSlFNTtAs.json: Could not fix the JSON structure.
# ./simple_output/almxlW77va98.json: fixed.
# ./simple_output/NxH2YWQ6XoTE.json: Could not fix the JSON structure.
# ./simple_output/1mFWVCJngYSj.json: fixed.
# ./simple_output/4ykCmRz9bQ3G.json: Could not fix the JSON structure.
# ./simple_output/yvfYEdWBHBDT.json: fixed.
# ./simple_output/nvLsNnJ2QcsO.json: fixed.
# ./simple_output/9CbfKcSgMDUJ.json: Could not fix the JSON structure.
# ./simple_output/tUfmuYXngzJ4.json: Could not fix the JSON structure.
# ./simple_output/kvWFFzE2Rxv5.json: JSON is valid, no changes made.
# ./simple_output/v4hBDr74EuFu.json: Could not fix the JSON structure.
# ./simple_output/eBcnV7MmFeae.json: Could not fix the JSON structure.
# ./simple_output/z5rw0cMCvGHq.json: Could not fix the JSON structure.
# ./simple_output/1Qrcausbix2n.json: Could not fix the JSON structure.
# ./simple_output/Y9LKkJm5isci.json: Could not fix the JSON structure.
# ./simple_output/le6Q5ESahE6H.json: Could not fix the JSON structure.
# ./simple_output/HaMKF7tPPybF.json: Could not fix the JSON structure.
# ./simple_output/UJ5KR58MXIil.json: Could not fix the JSON structure.
# ./simple_output/s49fPvY93CXW.json: Could not fix the JSON structure.
# ./simple_output/WBMxKwxYfweB.json: Could not fix the JSON structure.
# ./simple_output/Cq34H8wMueII.json: Could not fix the JSON structure.
# ./simple_output/yf6qxFK1X23C.json: fixed.
# ./simple_output/UE4rCYDuccJ1.json: fixed.
# ./simple_output/dcbqlQfxRxbr.json: Could not fix the JSON structure.
# ./simple_output/OhSd519yYYdr.json: Could not fix the JSON structure.
# ./simple_output/0plzyH6xBW2F.json: JSON is valid, no changes made.
# ./simple_output/6tJmnYVQCxLx.json: Could not fix the JSON structure.
# ./simple_output/qy1XsDm0GlyV.json: Could not fix the JSON structure.
# ./simple_output/qlA93MnApBk8.json: Could not fix the JSON structure.
# ./simple_output/NLVCk3kyhI01.json: fixed.
# ./simple_output/auUe0qvh7KKf.json: Could not fix the JSON structure.
# ./simple_output/4cF7RPaZ5wN3.json: Could not fix the JSON structure.
# ./simple_output/l3tdtDvccWFW.json: Could not fix the JSON structure.
# ./simple_output/mPI36zcmyGgs.json: Could not fix the JSON structure.
# ./simple_output/8reZ3NIXJus2.json: Could not fix the JSON structure.
# ./simple_output/c04CHoXJTTeQ.json: fixed.
# ./simple_output/DppQboAQwP79.json: Could not fix the JSON structure.
# ./simple_output/ZpcHpsbNk5wu.json: fixed.
# ./simple_output/9t4oG0LguIvk.json: fixed.
# ./simple_output/SGoy92ymyV6B.json: Could not fix the JSON structure.
# ./simple_output/CNO3NDdUUCrx.json: Could not fix the JSON structure.
# ./simple_output/rn6ROS3vgZS0.json: fixed.
# ./simple_output/6UObBC9s8i2D.json: fixed.
# ./simple_output/4TulEYJCrcDx.json: Could not fix the JSON structure.
# ./simple_output/WFTboNnBcm7K.json: fixed.
# ./simple_output/DzgUW9yFgF3h.json: Could not fix the JSON structure.
# ./simple_output/3ps4FFhd4Hy8.json: Could not fix the JSON structure.
# ./simple_output/uxG1UkZ0TAIS.json: Could not fix the JSON structure.
# ./simple_output/zkcb9MIxRgy9.json: Could not fix the JSON structure.
# ./simple_output/AWIrHPLilPrU.json: fixed.
# ./simple_output/cnQ2oHxxTtd0.json: fixed.
# ./simple_output/RZ8HJt5SITvG.json: fixed.
# ./simple_output/MIvDFT4ocxH9.json: Could not fix the JSON structure.
# ./simple_output/dvBffYpfpJDH.json: Could not fix the JSON structure.
# ./simple_output/WxwiZwVbloKs.json: Could not fix the JSON structure.
# ./simple_output/09KCtSGqzfN7.json: Could not fix the JSON structure.
# ./simple_output/el4a3rsAfab7.json: Could not fix the JSON structure.
# ./simple_output/WepiMvIS3EQq.json: fixed.
# ./simple_output/HCxjfOOg0iSn.json: fixed.
# ./simple_output/MHlhFZK6muVy.json: Could not fix the JSON structure.
# ./simple_output/jObzv3Vlhqny.json: Could not fix the JSON structure.
# ./simple_output/PaxwTBkHSD06.json: fixed.
# ./simple_output/xNpya9p50Pmd.json: fixed.
# ./simple_output/GZsXHDyidpYV.json: Could not fix the JSON structure.
# ./simple_output/srHfNHD0olMl.json: fixed.
# ./simple_output/lsLKWGpDsMG2.json: Could not fix the JSON structure.
# ./simple_output/xNpHvcXCNieG.json: fixed.
# ./simple_output/0f8phscvYzNy.json: JSON is valid, no changes made.
# ./simple_output/wmWBRmAXW7Nw.json: Could not fix the JSON structure.
# ./simple_output/Hq9RKQSr6zTF.json: Could not fix the JSON structure.
# ./simple_output/sB3edAqpzy50.json: fixed.
# ./simple_output/9A1JVZISp8SX.json: Could not fix the JSON structure.
# ./simple_output/cE7iXwg6kF6S.json: fixed.
# ./simple_output/7d6BmZ9hTm8U.json: Could not fix the JSON structure.
# ./simple_output/YTZf6bbpdGl0.json: Could not fix the JSON structure.
# ./simple_output/wbeBWn4kpqye.json: fixed.
# ./simple_output/k1njo7EgRWCh.json: fixed.
# ./simple_output/2PNKiO5Gki4p.json: fixed.
# ./simple_output/ye6KB8ydbEfK.json: Could not fix the JSON structure.
# ./simple_output/9VERSX1XrdH2.json: Could not fix the JSON structure.
# ./simple_output/5CpNFZwBXM0q.json: Could not fix the JSON structure.
# ./simple_output/5pJuMIN8RIWY.json: Could not fix the JSON structure.
# ./simple_output/FDlJwXmRGW1q.json: Could not fix the JSON structure.
# ./simple_output/ge5Gd7N0qVGa.json: Could not fix the JSON structure.
# ./simple_output/bpFiOjac9gyI.json: Could not fix the JSON structure.
# ./simple_output/QddJs5GMqo2T.json: Could not fix the JSON structure.
# ./simple_output/1h0toPkSVHBL.json: fixed.
# ./simple_output/OB1e8UgfGJ6V.json: fixed.
# ./simple_output/2NU4xLWY3jAv.json: Could not fix the JSON structure.
# ./simple_output/yaNP3LlJTg18.json: Could not fix the JSON structure.
# ./simple_output/3VmLdfGOQLR4.json: fixed.
# ./simple_output/i9DlSVnRlDdL.json: Could not fix the JSON structure.
# ./simple_output/sKxxUG1ESKgx.json: fixed.
# ./simple_output/1kRKVHM3KrPw.json: fixed.
# ./simple_output/6N3LdwyH93YE.json: fixed.
# ./simple_output/ZSWOUvAcZ1oy.json: fixed.
# ./simple_output/QMAP28IJu0ZJ.json: Could not fix the JSON structure.
# ./simple_output/eImsns9ZRO9D.json: Could not fix the JSON structure.
# ./simple_output/Lj5mRnz9hCvv.json: Could not fix the JSON structure.
# ./simple_output/pbB8PHTDKKbS.json: Could not fix the JSON structure.
# ./simple_output/nikfsiNmHNwi.json: Could not fix the JSON structure.
# ./simple_output/1gecOHwCxelE.json: JSON is valid, no changes made.
# ./simple_output/p0EcxjqRWC7e.json: Could not fix the JSON structure.
# ./simple_output/P6ibX4hjhr3h.json: Could not fix the JSON structure.
# ./simple_output/4QcOr9cvzZJ6.json: fixed.
# ./simple_output/V5RXVGoTbClY.json: Could not fix the JSON structure.
# ./simple_output/7utmCqu094TU.json: fixed.
# ./simple_output/udDBRw6MbiRu.json: fixed.
# ./simple_output/p17XD2ZflKFD.json: Could not fix the JSON structure.
# ./simple_output/Jiu4dN5poYy5.json: Could not fix the JSON structure.
# ./simple_output/HUSV1tPtiAFa.json: Could not fix the JSON structure.
# ./simple_output/CNRxokzpcR4R.json: fixed.
# ./simple_output/qI6Toj8AZ4kw.json: Could not fix the JSON structure.
# ./simple_output/n7RY22oq5sht.json: fixed.
# ./simple_output/0Kp9FQWsq5B9.json: JSON is valid, no changes made.
# ./simple_output/jZxK9N3diah5.json: Could not fix the JSON structure.
# ./simple_output/GZCjaQw3QqQ4.json: fixed.
# ./simple_output/Q5fQSioaVKqV.json: fixed.
# ./simple_output/dXsC1H3iHe5d.json: Could not fix the JSON structure.
# ./simple_output/lOxklCi75yAC.json: Could not fix the JSON structure.
# ./simple_output/OOpJhgvZ1htA.json: fixed.
# ./simple_output/v2Qu0GyVk4H1.json: Could not fix the JSON structure.
# ./simple_output/UcxAwcIfSyFL.json: Could not fix the JSON structure.
# ./simple_output/wmlsV06B6Zi9.json: fixed.
# ./simple_output/8FOIIzCV1pN6.json: Could not fix the JSON structure.
# ./simple_output/b1TaMHfdtvEu.json: fixed.
# ./simple_output/ZxNhS8GmE3gy.json: Could not fix the JSON structure.
# ./simple_output/nnVywNwd5JOV.json: Could not fix the JSON structure.
# ./simple_output/CHg874lMthmt.json: fixed.
# ./simple_output/NlXLrPyzJbWn.json: Could not fix the JSON structure.
# ./simple_output/MGdBpJm4uoBY.json: fixed.
# ./simple_output/wTa0DxHAYQ66.json: fixed.
# ./simple_output/c3o6QEeZPTBL.json: Could not fix the JSON structure.
# ./simple_output/1j97RCZ1owV0.json: Could not fix the JSON structure.
# ./simple_output/vF3oznXEDpaB.json: Could not fix the JSON structure.
# ./simple_output/UausSLTLXdcQ.json: fixed.
# ./simple_output/ZFWKoABMJ9CN.json: Could not fix the JSON structure.
# ./simple_output/L1OsX5hwpBWA.json: fixed.
# ./simple_output/ZZ1PHB3BZKfX.json: fixed.
# ./simple_output/gihy7eOChndf.json: Could not fix the JSON structure.
# ./simple_output/R7HjFAoPQuej.json: fixed.
# ./simple_output/fHHCStmRzb9x.json: fixed.
# ./simple_output/fFGDQ4oL8Jt2.json: fixed.
# ./simple_output/Y9vCKrBOUl4V.json: Could not fix the JSON structure.
# ./simple_output/LxtVI8Qisujv.json: Could not fix the JSON structure.
# ./simple_output/3WWxziLUYriK.json: Could not fix the JSON structure.
# ./simple_output/PcUnO7FmWfzG.json: Could not fix the JSON structure.
# ./simple_output/WfXayQ1xHScc.json: Could not fix the JSON structure.
# ./simple_output/qGd9FgrdXjij.json: fixed.
# ./simple_output/KacdqE8D2gHY.json: Could not fix the JSON structure.
# ./simple_output/YIV0pZpCRsI7.json: fixed.
# ./simple_output/QTCJrkcxDycR.json: Could not fix the JSON structure.
# ./simple_output/pOwddIsBIxir.json: Could not fix the JSON structure.
# ./simple_output/bMoFCqsTFxvE.json: fixed.
# ./simple_output/RGJ4KYGOzCPo.json: fixed.
# ./simple_output/Viz5uMGq2Mda.json: fixed.
# ./simple_output/MHXhAlzrj9t0.json: fixed.
# ./simple_output/j5URbVtpjBNU.json: Could not fix the JSON structure.
# ./simple_output/bc5QFdElGcnk.json: Could not fix the JSON structure.
# ./simple_output/EnvgMBgFLmfZ.json: Could not fix the JSON structure.
# ./simple_output/IhRRtUi0IQ1o.json: Could not fix the JSON structure.
# ./simple_output/nL8ljKFv5cgw.json: Could not fix the JSON structure.
# ./simple_output/Hq4xjBWYkiQm.json: fixed.
# ./simple_output/t7qWRbJcG4E0.json: fixed.
# ./simple_output/MO75pcl7NvSG.json: fixed.
# ./simple_output/pxuxU4NGDp1t.json: fixed.
# ./simple_output/cUczAfBUqFKo.json: fixed.
# ./simple_output/grdQit9dppgk.json: fixed.
# ./simple_output/HG6k2JoSYa2D.json: Could not fix the JSON structure.
# ./simple_output/IOKMDjtMF2r5.json: Could not fix the JSON structure.
# ./simple_output/Tg5LbAkYSk1G.json: fixed.
# ./simple_output/whIU5oGAYgQ6.json: fixed.
# ./simple_output/FZAySEfY4QMt.json: Could not fix the JSON structure.
# ./simple_output/FvdyeeeSd7rR.json: fixed.
# ./simple_output/nXyOVE6JZVTy.json: Could not fix the JSON structure.
# ./simple_output/1cf0ID0kNFxH.json: JSON is valid, no changes made.
# ./simple_output/Qiz154JR3qfE.json: Could not fix the JSON structure.
# ./simple_output/IvM7l8mAuY0e.json: Could not fix the JSON structure.
# ./simple_output/iLPyKHgtirAO.json: Could not fix the JSON structure.
# ./simple_output/SKIyCwGgtxHc.json: Could not fix the JSON structure.
# ./simple_output/DUqua6ItAduU.json: Could not fix the JSON structure.
# ./simple_output/A9oxWir3gNJi.json: fixed.
# ./simple_output/5qfWgbiFYcs3.json: Could not fix the JSON structure.
# ./simple_output/harPjchI0bK1.json: fixed.
# ./simple_output/s4uW9CIK0cJm.json: Could not fix the JSON structure.
# ./simple_output/TQsPY18NM25J.json: fixed.
# ./simple_output/QN3p9Etn0th4.json: Could not fix the JSON structure.
# ./simple_output/VvFebKunT1BN.json: fixed.
# ./simple_output/JwvXtqhTEwZe.json: Could not fix the JSON structure.
# ./simple_output/yWjyhsPLF4Aj.json: fixed.
# ./simple_output/iwbmO9vXWVdl.json: fixed.
# ./simple_output/GzOaeFIy9cy0.json: fixed.
# ./simple_output/lTEssosYshRt.json: Could not fix the JSON structure.
# ./simple_output/PKpygOz4T0ah.json: Could not fix the JSON structure.
# ./simple_output/rrU2kaKOsY04.json: Could not fix the JSON structure.
# ./simple_output/PV9etvimBpFC.json: Could not fix the JSON structure.
# ./simple_output/g0dLgEvzBYqh.json: Could not fix the JSON structure.
# ./simple_output/QsiZXvgpUpK4.json: Could not fix the JSON structure.
# ./simple_output/zD7upMKNFLth.json: Could not fix the JSON structure.
# ./simple_output/spMFWoQqRFyg.json: Could not fix the JSON structure.
# ./simple_output/769iTVaM8rCj.json: Could not fix the JSON structure.
# ./simple_output/dC9KKuL4eibp.json: fixed.
# ./simple_output/hi617xaOnfvN.json: Could not fix the JSON structure.
# ./simple_output/35wZrrWcdLlt.json: fixed.
# ./simple_output/E6Zp5Dm7JhcT.json: Could not fix the JSON structure.
# ./simple_output/ta9wIdIKmPFy.json: Could not fix the JSON structure.
# ./simple_output/fHeXYH2cD3mw.json: Could not fix the JSON structure.
# ./simple_output/gSHylSJWTgFB.json: Could not fix the JSON structure.
# ./simple_output/cv8JBFydRL2g.json: fixed.
# ./simple_output/EZTsi9SVCGcY.json: Could not fix the JSON structure.
# ./simple_output/PfHIH1sPXGpV.json: Could not fix the JSON structure.
# ./simple_output/1PGiLPFQzwOe.json: Could not fix the JSON structure.
# ./simple_output/I8aQFXSI4EmE.json: Could not fix the JSON structure.
# ./simple_output/QiC1amkXfWMX.json: Could not fix the JSON structure.
# ./simple_output/eqNcOpcA4jK6.json: Could not fix the JSON structure.
# ./simple_output/eDXidT8SrXMc.json: Could not fix the JSON structure.
# ./simple_output/HJFNfAc6wuSL.json: Could not fix the JSON structure.
# ./simple_output/rYIETex3Iz7C.json: Could not fix the JSON structure.
# ./simple_output/tbU3bq3P0mET.json: Could not fix the JSON structure.
# ./simple_output/ILH87AYfr8QY.json: fixed.
# ./simple_output/tqSFV87cKUSv.json: Could not fix the JSON structure.
# ./simple_output/AT9LLtYgOSW1.json: fixed.
# ./simple_output/xmRzO7GH2rrs.json: Could not fix the JSON structure.
# ./simple_output/F8hbcKdM4MEY.json: Could not fix the JSON structure.
# ./simple_output/OeaRTqLh6SXS.json: Could not fix the JSON structure.
# ./simple_output/iq9EhD97Nkrh.json: Could not fix the JSON structure.
# ./simple_output/HnbLPrRcIz4Z.json: Could not fix the JSON structure.
# ./simple_output/xwrbPcu9w6sJ.json: Could not fix the JSON structure.
# ./simple_output/iJLFFj24qYPG.json: fixed.
# ./simple_output/6NLXaWYbuamY.json: fixed.
# ./simple_output/nrpE5kBZjPOz.json: Could not fix the JSON structure.
# ./simple_output/DS4OHPLhZQPw.json: Could not fix the JSON structure.
# ./simple_output/FuEzwyEk1qe8.json: Could not fix the JSON structure.
# ./simple_output/Or4k56AmJPfs.json: Could not fix the JSON structure.
# ./simple_output/cmEihlp2R4Dl.json: Could not fix the JSON structure.
# ./simple_output/RYGk9RbQ1k6X.json: fixed.
# ./simple_output/aclnwfpH0DsF.json: Could not fix the JSON structure.
# ./simple_output/YdlpaUyYphWX.json: Could not fix the JSON structure.
# ./simple_output/4R0IXOc6ZkOR.json: Could not fix the JSON structure.
# ./simple_output/Av6WomaFdob4.json: Could not fix the JSON structure.
# ./simple_output/gzPBDY860bQU.json: Could not fix the JSON structure.
# ./simple_output/NrNztsUg67YM.json: fixed.
# ./simple_output/mBFkq1YzooJY.json: Could not fix the JSON structure.
# ./simple_output/tQORJ5XRBHIQ.json: Could not fix the JSON structure.
# ./simple_output/fGlFIGVFV0MX.json: fixed.
# ./simple_output/zHQ5VSOJR8H8.json: Could not fix the JSON structure.
# ./simple_output/Bk9bi4wqW5yb.json: fixed.
# ./simple_output/nEn73RypiAwf.json: fixed.
# ./simple_output/wnVdbqWOBkFE.json: Could not fix the JSON structure.
# ./simple_output/5fVtflPFb7v5.json: Could not fix the JSON structure.
# ./simple_output/yZe2hMtZfZ44.json: fixed.
# ./simple_output/72jL05ECCq1h.json: Could not fix the JSON structure.
# ./simple_output/HWiE9YGuKVq9.json: fixed.
# ./simple_output/6oPeFHUb0PyN.json: fixed.
# ./simple_output/P26y17IFQ9Ok.json: fixed.
# ./simple_output/dqi762PeAPL7.json: Could not fix the JSON structure.
# ./simple_output/BJQ1e0uWgpfD.json: fixed.
# ./simple_output/d7BeCosGIxa5.json: fixed.
# ./simple_output/aWqO7PjZw6Pl.json: Could not fix the JSON structure.
# ./simple_output/T4VSCK5rVyzw.json: Could not fix the JSON structure.
# ./simple_output/PNLLcE5VxvZ7.json: Could not fix the JSON structure.
# ./simple_output/cNEiyz4eH1DG.json: Could not fix the JSON structure.
# ./simple_output/d3nacqr0b0yU.json: fixed.
# ./simple_output/3KfG9IsCXxvW.json: Could not fix the JSON structure.
# ./simple_output/7iFhn5XazcGt.json: Could not fix the JSON structure.
# ./simple_output/grz0Tl5BdKpl.json: Could not fix the JSON structure.
# ./simple_output/eepV9njTNgM5.json: Could not fix the JSON structure.
# ./simple_output/mhaNQKp2XF73.json: Could not fix the JSON structure.
# ./simple_output/h9pUJyhOkSSq.json: Could not fix the JSON structure.
# ./simple_output/nsjzzgxijL3I.json: fixed.
# ./simple_output/ny8rieuYFUk2.json: Could not fix the JSON structure.
# ./simple_output/Wph5mjyXnz3U.json: Could not fix the JSON structure.
# ./simple_output/LW78Ns5b25Mr.json: Could not fix the JSON structure.
# ./simple_output/mBZ1gPMdVlzF.json: fixed.
# ./simple_output/bGGSTzDEtU4S.json: fixed.
# ./simple_output/HT1hp3LJO82P.json: Could not fix the JSON structure.
# ./simple_output/DZIlohwiLbk2.json: fixed.
# ./simple_output/QvwWV9lNM68d.json: Could not fix the JSON structure.
# ./simple_output/8LBPJyJcs7pL.json: Could not fix the JSON structure.
# ./simple_output/VdsQAHjikyXd.json: Could not fix the JSON structure.
# ./simple_output/reDIWEehS8ie.json: Could not fix the JSON structure.
# ./simple_output/vbSUECr2modu.json: fixed.
# ./simple_output/8DwJ5U9q27dL.json: Could not fix the JSON structure.
# ./simple_output/4xGsK2USPUu9.json: Could not fix the JSON structure.
# ./simple_output/scywuvJjFnjE.json: Could not fix the JSON structure.
# ./simple_output/ezAcbkAKMBk5.json: Could not fix the JSON structure.
# ./simple_output/qcGkxXy2eMho.json: Could not fix the JSON structure.
# ./simple_output/t4gUSVlMHVKq.json: Could not fix the JSON structure.
# ./simple_output/hhVhqQxKD9gp.json: Could not fix the JSON structure.
# ./simple_output/Vzdyoyh1JtYc.json: fixed.
# ./simple_output/vJZQB2m1rclF.json: Could not fix the JSON structure.
# ./simple_output/7FYjnaKBH2U5.json: Could not fix the JSON structure.
# ./simple_output/g29ihOSVv8BT.json: fixed.
# ./simple_output/vdoZ06VeIo7e.json: fixed.
# ./simple_output/3Y7QdN7fac3J.json: fixed.
# ./simple_output/qUCnWgwlI1tT.json: fixed.
# ./simple_output/1LJvZqdO8bLl.json: Could not fix the JSON structure.
# ./simple_output/dJEHG4MeRKUp.json: Could not fix the JSON structure.
# ./simple_output/6hJASBxgNVbE.json: Could not fix the JSON structure.
# ./simple_output/aI7M4wDU1pZF.json: fixed.
# ./simple_output/27B2ISuMvsep.json: fixed.
# ./simple_output/ko6d4iySMbfd.json: Could not fix the JSON structure.
# ./simple_output/ZeDKzWAJuXW4.json: fixed.
# ./simple_output/iNhSEfiDxxoi.json: Could not fix the JSON structure.
# ./simple_output/JO7xO0pJy2te.json: Could not fix the JSON structure.
# ./simple_output/m3G7VFzl3MnE.json: Could not fix the JSON structure.
# ./simple_output/gAv4PBYYxORI.json: Could not fix the JSON structure.
# ./simple_output/2noy4A2opiG2.json: fixed.
# ./simple_output/fhuoRkn0SASP.json: Could not fix the JSON structure.
# ./simple_output/5Y8xnRyyuY8W.json: Could not fix the JSON structure.
# ./simple_output/CR5kQfYL22bN.json: Could not fix the JSON structure.
# ./simple_output/ideyIi9AEXVt.json: Could not fix the JSON structure.
# ./simple_output/gVH5cHuVeaEQ.json: Could not fix the JSON structure.
# ./simple_output/ZnpU68QMm39O.json: Could not fix the JSON structure.
# ./simple_output/llTHRqHWHwHI.json: Could not fix the JSON structure.
# ./simple_output/SYjikgHdTpve.json: Could not fix the JSON structure.
# ./simple_output/jZY7wrxZ0UcY.json: Could not fix the JSON structure.
# ./simple_output/3pt2HCIvalEj.json: Could not fix the JSON structure.
# ./simple_output/eq9ZIJY6MqME.json: Could not fix the JSON structure.
# ./simple_output/nSDj9v4QRtqZ.json: Could not fix the JSON structure.
# ./simple_output/supJRquWIbvL.json: Could not fix the JSON structure.
# ./simple_output/CHzbuggk7EA1.json: fixed.
# ./simple_output/iZ42tfOqMKcS.json: Could not fix the JSON structure.
# ./simple_output/VznyAB4lxgug.json: fixed.
# ./simple_output/g5IplAJJUAz9.json: Could not fix the JSON structure.
# ./simple_output/oiKkkFQo5Psu.json: fixed.
# ./simple_output/byAd6OXUcHYY.json: JSON is valid, no changes made.
# ./simple_output/Lxwy0ChAK9FL.json: fixed.
# ./simple_output/ThStxq7iE8q0.json: fixed.
# ./simple_output/4UJFYTgIyCmU.json: Could not fix the JSON structure.
# ./simple_output/drKUirR3THEz.json: Could not fix the JSON structure.
# ./simple_output/uUvk2aoP4pHi.json: Could not fix the JSON structure.
# ./simple_output/fBP9dAazCTMe.json: fixed.
# ./simple_output/MGUn7IRnoPHb.json: fixed.
# ./simple_output/Tt43QGEDjQfg.json: Could not fix the JSON structure.
# ./simple_output/zfCx70FnRQBz.json: Could not fix the JSON structure.
# ./simple_output/wySRUdjpl5i4.json: Could not fix the JSON structure.
# ./simple_output/kgQB1WNpCeNf.json: fixed.
# ./simple_output/fgGGWew0KoCo.json: JSON is valid, no changes made.
# ./simple_output/Xa0NP1aQ2NQ7.json: Could not fix the JSON structure.
# ./simple_output/QD2Ms7u8SJun.json: fixed.
# ./simple_output/VUQR91G9TeqA.json: fixed.
# ./simple_output/QSF6Ruq7cv22.json: fixed.
# ./simple_output/UU313botf4Uv.json: Could not fix the JSON structure.
# ./simple_output/1HtJauS9EblC.json: Could not fix the JSON structure.
# ./simple_output/feqOFxGwab59.json: fixed.
# ./simple_output/Qj2hKEtc5lww.json: Could not fix the JSON structure.
# ./simple_output/y3aAmdDkOrwc.json: Could not fix the JSON structure.
# ./simple_output/XvObAblomkb3.json: Could not fix the JSON structure.
# ./simple_output/kgqGFk44f9MZ.json: fixed.
# ./simple_output/GKqbXh24E04Y.json: fixed.
# ./simple_output/BADGWO6hxjYH.json: fixed.
# ./simple_output/uADGcz2EEaxT.json: Could not fix the JSON structure.
# ./simple_output/uU7Qffi9onRR.json: fixed.
# ./simple_output/H14pfksjWUiQ.json: Could not fix the JSON structure.
# ./simple_output/4Z7eqcylXYh3.json: fixed.
# ./simple_output/4z7iCL1vUVrd.json: Could not fix the JSON structure.
# ./simple_output/ZTfpD56SFMh8.json: Could not fix the JSON structure.
# ./simple_output/QhzNBRmBPLaL.json: Could not fix the JSON structure.
# ./simple_output/tsAijAiGXHns.json: fixed.
# ./simple_output/1N2AtrbvTABW.json: fixed.
# ./simple_output/fXK7js1EjxJv.json: Could not fix the JSON structure.
# ./simple_output/JYKKKof7Gn94.json: fixed.
# ./simple_output/C5TxFJLpox6o.json: Could not fix the JSON structure.
# ./simple_output/uM6ItGRsdewt.json: Could not fix the JSON structure.
# ./simple_output/HdBrlchdLFeA.json: fixed.
# ./simple_output/AAVSuNCqdVCo.json: Could not fix the JSON structure.
# ./simple_output/TdBz0CuGqXlW.json: fixed.
# ./simple_output/n6QpCZG3Alje.json: fixed.
# ./simple_output/e2BNPE0V018o.json: Could not fix the JSON structure.
# ./simple_output/pvDueotgX3cH.json: fixed.
# ./simple_output/rINuxZFGI7Er.json: fixed.
# ./simple_output/4bAj1Me052cz.json: fixed.
# ./simple_output/6fLjRIKEu77K.json: fixed.
